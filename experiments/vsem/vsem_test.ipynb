# %%
# tests_and_example.py
import numpy as onp
import jax
import jax.numpy as jnp
from functools import partial

import vsem as vsem_numpy
from vsem_jax import make_vsem_input_from_named, solve_vsem_jax, get_vsem_driver
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 8
#       5 from functools import partial
#       7 import vsem as vsem_numpy
# ----> 8 from vsem_jax import solve_vsem_jax, get_vsem_driver
#
# ImportError: cannot import name 'get_vsem_driver' from 'vsem_jax' (/Users/andrewroberts/Desktop/git-repos/bip-surrogates-paper/experiments/vsem/vsem_jax.py)

# %%
import vsem_jax

# %%
# driver is 1D numpy or jnp array:
_, driver = get_vsem_driver(200)   # use your old helper or generate externally

params = {"lue": 0.002, "gamma": 0.4, "veg_init": 3.0}
vsem_input = make_vsem_input_from_named(params, driver)
# out = solve_vsem_jax(vsem_input)  # jnp array shape (n_days, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # driver is 1D numpy or jnp array:
# ----> 2 _, driver = get_vsem_driver(200)   # use your old helper or generate externally
#       4 params = {"lue": 0.002, "gamma": 0.4, "veg_init": 3.0}
#       5 vsem_input = make_vsem_input_from_named(params, driver)
#
# NameError: name 'get_vsem_driver' is not defined
